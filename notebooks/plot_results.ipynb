# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

# %%
data = np.loadtxt("/home/rhys/work/sampnn/test_results.csv", delimiter=",")

# %%
plt.plot(data[:,1], data[:,2],'x')
plt.plot((np.min(data[:,1:]),np.max(data[:,1:])), (np.min(data[:,1:]),np.max(data[:,1:])), 'r--')
plt.xlim((np.min(data[:,1:]),np.max(data[:,1:])))
plt.ylim((np.min(data[:,1:]),np.max(data[:,1:])))
plt.show()

# %%
print(r2_score(data[:,1],data[:,2]))
# Out:
# 0.12487768016687639
